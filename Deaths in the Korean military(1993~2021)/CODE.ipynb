# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('data.xlsx', index_col=0)
df
# Out:
#         1993 1994 1995  1996  1997  1998 1999 2000 2001 2002  ... 2012 2013  \
# 계        343  416  330   359   273   248  230  182  164  158  ...  111  117
# 안전사고     202  238  222   243   173   136  116   96   95   72  ...   38   37
# - 차량      54  126  138   100    83    42   62   43   37   34  ...   17   15
# - 항공/함정   12   11    9     2     9     7    3    3    5    5  ...    1    2
# - 익사       -    -   24    23    21    33   14   14   19    9  ...    2    6
# - 폭발      12    8    4     5    11    12    1    1    2    2  ...    -    -
# - 추락/충격    -    -   20    19    12     9   17   12   11   12  ...    5    7
# - 화재       -    -    3     2     1     1    -    -    1    -  ...    3    -
# - 기타     124   93   24    92    36    32   19   23   20   10  ...   10    7
# 군기사고     141  178  108   116   100   112  114   86   69   86  ...   73   80
# - 자살     129  155  100   103    92   102  101   82   66   79  ...   72   79
# ...
